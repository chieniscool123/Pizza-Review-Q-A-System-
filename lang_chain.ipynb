# %%
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
import os
import pandas as pd
from vector import retriever

# %%
model = OllamaLLM(model = "llama2")
template = """
You are an exeprt in answering questions about a pizza restaurant

Here are some relevant reviews: {reviews}

Here is the question to answer: {question}
"""

# %%
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | model

# %%
while True:
    print("\n\n-------------------------------")
    question = input("Ask your question (q to quit): ")
    print("\n\n")
    if question == "q":
        break
    
    reviews = retriever.invoke(question)
    result = chain.invoke({"reviews": reviews, "question": question})
    print(question)
    print(result)
# Out:
# -------------------------------
#
#
#
# What type of meat are there ?
#  Based on the reviews provided, there are several types of meat available at the pizza restaurant:
#
# 1. Soppressata: Mentioned in the review as a standout option in the "Butcher's Block" pizza.
# 2. House-made sausage: Also mentioned in the same review as a standout option in the "Butcher's Block" pizza.
# 3. Buffalo mozzarella: Mentioned in one of the reviews as an ingredient in their Margherita pizza that melts in your mouth.
# 4. Olives: Mentioned in multiple reviews as an ingredient on some of their pizzas, including the "Mediterranean" pizza.
# 5. Feta: Mentioned in one of the reviews as an ingredient on some of their pizzas.
# 6. Peas: Mentioned in one of the reviews as an ingredient on their spring-themed seasonal pizza.
# 7. Asparagus: Mentioned in one of the reviews as an ingredient on their spring-themed seasonal pizza.
# 8. Green garlic: Mentioned in one of the reviews as an ingredient on their spring-themed seasonal pizza.
#
# There may be other types of meat available as well, but these are the ones specifically mentioned in the reviews provided.
#
#
# -------------------------------
